# %%
# !zenml init
# Out:
# Found existing ZenML repository at path '/home/jovyan/work'.
# ⠋ Initializing ZenML repository at /home/jovyan/work.
# ⠋ Initializing ZenML repository at /home/jovyan/work.

# %%
from zenml import step, pipeline

# Step 1
@step
def load_data() -> list:
    return [1, 2, 3, 4]

# Step 2
@step
def multiply(data: list) -> list:
    return [x * 2 for x in data]

# Step 3
@step
def trainer(data: list) -> int:
    return sum(data)

# Pipeline
@pipeline
def my_pipeline():
    data = load_data()
    processed = multiply(data)
    trainer(processed)

# %%
my_pipeline()
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:1                                                                                    │
# │                                                                                                  │
# │ ❱ 1 my_pipeline()                                                                                │
# │   2                                                                                              │
# │                                                                                                  │
# │ /opt/conda/lib/python3.10/site-packages/zenml/pipelines/pipeline_definition.py:1585 in __call__  │
# │                                                                                                  │
# │   1582 │   │   │   return self.entrypoint(*args, **kwargs)  # type: ignore[no-any-return]        │
# │   1583 │   │                                                                                     │
# │   1584 │   │   self.prepare(*args, **kwargs)                                                     │
# │ ❱ 1585 │   │   return self._run()                                                                │
# │   1586 │                                                                                         │
# │   1587 │   def _call_entrypoint(self, *args: Any, **kwargs: Any) -> Any:                         │
# │   1588 │   │   """Calls the pipeline entrypoint function with the given arguments.               │
# │                                                                                                  │
# │ /opt/conda/lib/python3.10/site-packages/zenml/pipelines/pipeline_definition.py:1046 in _run      │
# │                                                                                                  │
# │   1043 │   │                                                                                     │
# │   1044 │   │   logs_context: ContextManager[Any] = nullcontext()                                 │
# │   1045 │   │   if is_pipeline_logging_enabled(self.configuration):                               │
# │ ❱ 1046 │   │   │   logs_context = setup_logging_context(source="client")                         │
# │   1047 │   │                                                                                     │
# │   1048 │   │   with logs_context:                                                                │
# │   1049 │   │   │   logger.info(                                                                  │
# │                                                                                                  │
# │ /opt/conda/lib/python3.10/site-packages/zenml/utils/logging_utils.py:571 in                      │
# │ setup_logging_context                                                                            │
# │                                                                                                  │
# │   568 │   """                                                                                    │
# │   569 │   log_metadata = {}                                                                      │
# │   570 │                                                                                          │
# │ ❱ 571 │   logs_request = generate_logs_request(source=source)                                    │
# │   572 │                                                                                          │
# │   573 │   if step_run:                                                                           │
# │   574 │   │   log_metadata.update(get_step_log_metadata(step_run=step_run))                      │
# │                                                                                                  │
# │ /opt/conda/lib/python3.10/site-packages/zenml/utils/logging_utils.py:287 in                      │
# │ generate_logs_request                                                                            │
# │                                                                                                  │
# │   284 │   │   prepare_logs_uri,                                                                  │
# │   285 │   )                                                                                      │
# │   286 │                                                                                          │
# │ ❱ 287 │   client = Client()                                                                      │
# │   288 │   log_store = client.active_stack.log_store                                              │
# │   289 │   log_id = uuid4()                                                                       │
# │   290                                                                                            │
# │                                                                                                  │
# │ /opt/conda/lib/python3.10/site-packages/zenml/client.py:325 in __call__                          │
# │                                                                                                  │
# │    322 │   │                                                                                     │
# │    323 │   │   if not cls._global_client:                                                        │
# │    324 │   │   │   cls._global_client = cast(                                                    │
# │ ❱  325 │   │   │   │   "Client", super().__call__(*args, **kwargs)                               │
# │    326 │   │   │   )                                                                             │
# │    327 │   │                                                                                     │
# │    328 │   │   return cls._global_client                                                         │
# │                                                                                                  │
# │ /opt/conda/lib/python3.10/site-packages/zenml/client_lazy_loader.py:213 in _inner                │
# │                                                                                                  │
# │   210 │   │   │   │   │   with contextlib.suppress(ValueError):                                  │
# │   211 │   │   │   │   │   │   kwargs[k] = ClientLazyLoader(**v).evaluate()                       │
# │   212 │   │   │                                                                                  │
# │ ❱ 213 │   │   │   return func(*args_, **kwargs)                                                  │
# │   214 │   │                                                                                      │
# │   215 │   │   return _inner                                                                      │
# │   216                                                                                            │
# │                                                                                                  │
# │ /opt/conda/lib/python3.10/site-packages/zenml/client.py:398 in __init__                          │
# │                                                                                                  │
# │    395 │   │   self._root: Optional[Path] = None                                                 │
# │    396 │   │   self._config: Optional[ClientConfiguration] = None                                │
# │    397 │   │                                                                                     │
# │ ❱  398 │   │   self._set_active_root(root)                                                       │
# │    399 │                                                                                         │
# │    400 │   @classmethod                                                                          │
# │    401 │   def get_instance(cls) -> Optional["Client"]:                                          │
# │                                                                                                  │
# │ /opt/conda/lib/python3.10/site-packages/zenml/client_lazy_loader.py:213 in _inner                │
# │                                                                                                  │
# │   210 │   │   │   │   │   with contextlib.suppress(ValueError):                                  │
# │   211 │   │   │   │   │   │   kwargs[k] = ClientLazyLoader(**v).evaluate()                       │
# │   212 │   │   │                                                                                  │
# │ ❱ 213 │   │   │   return func(*args_, **kwargs)                                                  │
# │   214 │   │                                                                                      │
# │   215 │   │   return _inner                                                                      │
# │   216                                                                                            │
# │                                                                                                  │
# │ /opt/conda/lib/python3.10/site-packages/zenml/client.py:455 in _set_active_root                  │
# │                                                                                                  │
# │    452 │   │                                                                                     │
# │    453 │   │   # Sanitize the client configuration to reflect the current                        │
# │    454 │   │   # settings                                                                        │
# │ ❱  455 │   │   self._sanitize_config()                                                           │
# │    456 │                                                                                         │
# │    457 │   def _config_path(self) -> Optional[str]:                                              │
# │    458 │   │   """Path to the client configuration file.                                         │
# │                                                                                                  │
# │ /opt/conda/lib/python3.10/site-packages/zenml/client_lazy_loader.py:213 in _inner                │
# │                                                                                                  │
# │   210 │   │   │   │   │   with contextlib.suppress(ValueError):                                  │
# │   211 │   │   │   │   │   │   kwargs[k] = ClientLazyLoader(**v).evaluate()                       │
# │   212 │   │   │                                                                                  │
# │ ❱ 213 │   │   │   return func(*args_, **kwargs)                                                  │
# │   214 │   │                                                                                      │
# │   215 │   │   return _inner                                                                      │
# │   216                                                                                            │
# │                                                                                                  │
# │ /opt/conda/lib/python3.10/site-packages/zenml/client.py:478 in _sanitize_config                  │
# │                                                                                                  │
# │    475 │   │   if not self._config:                                                              │
# │    476 │   │   │   return                                                                        │
# │    477 │   │                                                                                     │
# │ ❱  478 │   │   active_project, active_stack = self.zen_store.validate_active_config(             │
# │    479 │   │   │   self._config.active_project_id,                                               │
# │    480 │   │   │   self._config.active_stack_id,                                                 │
# │    481 │   │   │   config_name="repo",                                                           │
# │                                                                                                  │
# │ /opt/conda/lib/python3.10/site-packages/zenml/client.py:661 in zen_store                         │
# │                                                                                                  │
# │    658 │   │   Returns:                                                                          │
# │    659 │   │   │   The global zen store.                                                         │
# │    660 │   │   """                                                                               │
# │ ❱  661 │   │   return GlobalConfiguration().zen_store                                            │
# │    662 │                                                                                         │
# │    663 │   @property                                                                             │
# │    664 │   def root(self) -> Optional[Path]:                                                     │
# │                                                                                                  │
# │ /opt/conda/lib/python3.10/site-packages/zenml/config/global_config.py:230 in                     │
# │ __custom_getattribute__                                                                          │
# │                                                                                                  │
# │   227 │   │   Returns:                                                                           │
# │   228 │   │   │   The attribute value.                                                           │
# │   229 │   │   """                                                                                │
# │ ❱ 230 │   │   value = super().__getattribute__(key)                                              │
# │   231 │   │   if key.startswith("_") or key not in type(self).model_fields:                      │
# │   232 │   │   │   return value                                                                   │
# │   233                                                                                            │
# │                                                                                                  │
# │ /opt/conda/lib/python3.10/site-packages/zenml/config/global_config.py:750 in zen_store           │
# │                                                                                                  │
# │   747 │   │   │   The current zen store.                                                         │
# │   748 │   │   """                                                                                │
# │   749 │   │   if self._zen_store is None:                                                        │
# │ ❱ 750 │   │   │   self._configure_store(self.store_configuration)                                │
# │   751 │   │   assert self._zen_store is not None                                                 │
# │   752 │   │                                                                                      │
# │   753 │   │   return self._zen_store                                                             │
# │                                                                                                  │
# │ /opt/conda/lib/python3.10/site-packages/zenml/config/global_config.py:230 in                     │
# │ __custom_getattribute__                                                                          │
# │                                                                                                  │
# │   227 │   │   Returns:                                                                           │
# │   228 │   │   │   The attribute value.                                                           │
# │   229 │   │   """                                                                                │
# │ ❱ 230 │   │   value = super().__getattribute__(key)                                              │
# │   231 │   │   if key.startswith("_") or key not in type(self).model_fields:                      │
# │   232 │   │   │   return value                                                                   │
# │   233                                                                                            │
# │                                                                                                  │
# │ /opt/conda/lib/python3.10/site-packages/zenml/config/global_config.py:658 in store_configuration │
# │                                                                                                  │
# │   655 │   │   # configuration from there and disregard the global configuration.                 │
# │   656 │   │   if self._zen_store is not None:                                                    │
# │   657 │   │   │   return self._zen_store.config                                                  │
# │ ❱ 658 │   │   return self.get_store_configuration()                                              │
# │   659 │                                                                                          │
# │   660 │   def get_default_store(self) -> StoreConfiguration:                                     │
# │   661 │   │   """Get the default SQLite store configuration.                                     │
# │                                                                                                  │
# │ /opt/conda/lib/python3.10/site-packages/zenml/config/global_config.py:591 in                     │
# │ get_store_configuration                                                                          │
# │                                                                                                  │
# │   588 │   │   if not store:                                                                      │
# │   589 │   │   │   if not allow_default:                                                          │
# │   590 │   │   │   │   return None                                                                │
# │ ❱ 591 │   │   │   store = self.get_default_store()                                               │
# │   592 │   │                                                                                      │
# │   593 │   │   # Step 3: Replace or update the baseline secrets store configuration               │
# │   594 │   │   # with the environment variables. This only applies to SQL stores.                 │
# │                                                                                                  │
# │ /opt/conda/lib/python3.10/site-packages/zenml/config/global_config.py:668 in get_default_store   │
# │                                                                                                  │
# │   665 │   │   """                                                                                │
# │   666 │   │   from zenml.zen_stores.base_zen_store import BaseZenStore                           │
# │   667 │   │                                                                                      │
# │ ❱ 668 │   │   return BaseZenStore.get_default_store_config(                                      │
# │   669 │   │   │   path=os.path.join(                                                             │
# │   670 │   │   │   │   self.local_stores_path,                                                    │
# │   671 │   │   │   │   DEFAULT_STORE_DIRECTORY_NAME,                                              │
# │                                                                                                  │
# │ /opt/conda/lib/python3.10/site-packages/zenml/zen_stores/base_zen_store.py:260 in                │
# │ get_default_store_config                                                                         │
# │                                                                                                  │
# │   257 │   │   Returns:                                                                           │
# │   258 │   │   │   The default store configuration.                                               │
# │   259 │   │   """                                                                                │
# │ ❱ 260 │   │   from zenml.zen_stores.secrets_stores.sql_secrets_store import (                    │
# │   261 │   │   │   SqlSecretsStoreConfiguration,                                                  │
# │   262 │   │   )                                                                                  │
# │   263 │   │   from zenml.zen_stores.sql_zen_store import SqlZenStoreConfiguration                │
# │                                                                                                  │
# │ /opt/conda/lib/python3.10/site-packages/zenml/zen_stores/secrets_stores/sql_secrets_store.py:40  │
# │ in <module>                                                                                      │
# │                                                                                                  │
# │    37 from pydantic import ConfigDict                                                            │
# │    38 from sqlalchemy.engine import Engine                                                       │
# │    39 from sqlalchemy.exc import NoResultFound                                                   │
# │ ❱  40 from sqlalchemy_utils.types.encrypted.encrypted_type import AesGcmEngine                   │
# │    41 from sqlmodel import Session, select                                                       │
# │    42                                                                                            │
# │    43 from zenml.config.secrets_store_config import SecretsStoreConfiguration                    │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# ModuleNotFoundError: No module named 'sqlalchemy_utils'

# %%
from zenml.client import Client

client = Client()
print(client.list_pipeline_runs())
