# %%
# !python run_pipeline.py
# Out:
# Initiating a new run for the pipeline: train_pipeline.
# Initializing the ZenML global configuration version to 0.58.2
# ╭───────────────────── Traceback (most recent call last) ──────────────────────╮
# │ /home/jovyan/work/run_pipeline.py:4 in <module>                              │
# │                                                                              │
# │   1 from pipelines.training_pipeline import train_pipeline                   │
# │   2                                                                          │
# │   3 if __name__ == "__main__":                                               │
# │ ❱ 4 │   train_pipeline(                                                      │
# │   5 │   │   data_path="data/olist_customers_dataset.csv"                     │
# │   6 │   )                                                                    │
# │   7                                                                          │
# ...

# %%
# !zenml connect --url http://zenml-server:8080
# Out:
# Connecting to: 'http://zenml-server:8080'...
# If your browser did not open automatically, please open the following URL into your browser to proceed with the authentication:
#
# http://zenml-server:8080/devices/verify?device_id=ac5c85d3-a244-4ff3-b568-d1f502d5439a&user_code=0efcef62e6c50db3ab82ac38184d702f
#
# ╭───────────────────── Traceback (most recent call last) ──────────────────────╮
# │ /opt/conda/bin/zenml:6 in <module>                                           │
# │                                                                              │
# │   3 from zenml.cli.cli import cli                                            │
# │   4 if __name__ == '__main__':                                               │
# │   5 │   sys.argv[0] = sys.argv[0].removesuffix('.exe')                       │
# │ ❱ 6 │   sys.exit(cli())                                                      │
# │   7                                                                          │
# ...
