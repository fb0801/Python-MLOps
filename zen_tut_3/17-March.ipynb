# %%
# !zenml status
# Out:
# Initializing the ZenML global configuration version to 0.94.0
# Creating database tables
# Creating default project 'default' ...
# Creating default stack...
# Setting the global active project to 'default'.
# Setting the global active stack to default.
# -----ZenML Client Status-----
# Connected to the local ZenML database:
# 'sqlite:////home/jovyan/.config/zenml/local_stores/default_zen_store/zenml.db'
#   The active user is: 'default'
#   The active project is: 'default' (global)
#   The active stack is: 'default' (global)
# Using configuration from: '/home/jovyan/.config/zenml'
# Local store files are located at: '/home/jovyan/.config/zenml/local_stores'
#
# -----Local ZenML Server Status-----
# The local server has not been started.

# %%
# !zenml login http://host.docker.internal:8237
# Out:
# Initializing the ZenML global configuration version to 0.94.0
# Retrying (Retry(total=9, connect=4, read=8, redirect=3, status=10)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0xffffa0c8ee00>: Failed to establish a new connection: [Errno 111] Connection refused')': /api/v1/info
# Retrying (Retry(total=8, connect=3, read=8, redirect=3, status=10)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0xffffa0c8f520>: Failed to establish a new connection: [Errno 111] Connection refused')': /api/v1/info
# ^C
#
# Aborted!
